# %%
import pandas as pd

# %%
df = pd.read_excel(open('/Users/huzhenyu/Downloads/ZORO车型属性标注_苏格拉底属性映射.xlsx','rb'))

# %%
df[0:10]
# Out:
#              ZORO任务名称      标注车型属性名称    数值       苏格拉底车型属性名称 Unnamed: 4  数值.1
# 0  车型属性（后排座椅-是否有中央头枕）  后排座椅.是否有中央头枕     是  车型.后排座椅.是否有中央头枕        NaN     是
# 1                 NaN           NaN     否              NaN        NaN     否
# 2    车型属性（后排座椅-地板平整度）    后排座椅.地板平整度    纯平    车型.后排座椅.地板平整度        NaN    纯平
# 3                 NaN           NaN  几乎纯平              NaN        NaN  几乎纯平
# 4                 NaN           NaN   小鼓包              NaN        NaN   小鼓包
# 5                 NaN           NaN   大鼓包              NaN        NaN   大鼓包
# 6         车型属性（整车-线条）         整车.线条    修长         车型.整车.线条         多值    修长
# 7                 NaN           NaN    大气              NaN        NaN    大气
# 8                 NaN           NaN    流畅              NaN        NaN    流畅
# 9                 NaN           NaN    平直              NaN        NaN    平直

# %%
pd.set_option('max_columns', None)

# %%
pd.set_option('max_colwidth', None)

# %%
df
# Out:
#                                             车头  \
# 0                                          NaN
# 1                                     schema名称
# 2                                        前脸.风格
# 3                                     前脸.饰物.材质
# 4                                     前脸.饰物.名称
# ..                                         ...
# 75                                     前排座椅.颜色
# 76                                  后排座椅.地板平整度
# 77                                后排座椅.是否有中央头枕
# 78                                         NaN
# 79  选图逻辑：\n按照车型粒度打标，选取任务一图片五级标签分类任务中已完成打标的车型图片
#
#                                                                                       Unnamed: 1  \
# 0                                                                                            NaN
# 1                                                                                             图片
# 2   外观-正前\n外观-左前\n外观-右前\n外观-左侧\n细节-车头-格栅-正拍\n细节-车头-格栅-斜拍\n细节-车头-前大灯-左侧-45度斜拍\n细节-车头-前大灯-右侧-45度斜拍
# 3                                                                                            NaN
# 4                                                                                            NaN
# ..                                                                                           ...
# 75                                                                                           NaN
# 76                                                                                           NaN
# 77                                                                                           NaN
# 78                                                                                           NaN
# 79                                                                                           NaN
#
#     Unnamed: 2  Unnamed: 3
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# ..         ...         ...
# 75         NaN         NaN
# 76         NaN         NaN
# 77         NaN         NaN
# 78         NaN         NaN
# 79         NaN         NaN
#
# [80 rows x 4 columns]

# %%
pd.reset_option('max_columns')

# %%
pd.set_option('display.max_rows', df.shape[0]+1)
print(df)
# Out:
#                                             车头  \
# 0                                          NaN
# 1                                     schema名称
# 2                                        前脸.风格
# 3                                     前脸.饰物.材质
# 4                                     前脸.饰物.名称
# 5                                  前脸.饰物.是否贯穿式
# 6                                     前脸.饰物.颜色
# 7                                        前脸.线条
# 8                                        整车.风格
# 9                                        整车.线条
# 10                                    格栅.饰物.材质
# 11                                    格栅.饰物.名称
# 12                                    格栅.饰物.颜色
# 13                                       格栅.造型
# 14                                    格栅.中网.风格
# 15                                    格栅.中网.造型
# 16                                       大灯.风格
# 17                                          车侧
# 18                                         NaN
# 19                                    schema名称
# 20                                       车侧.风格
# 21                                    车侧.饰物.材质
# 22                                    车侧.饰物.名称
# 23                                    车侧.饰物.颜色
# 24                                    车侧.是否溜背式
# 25                                  车侧.是否悬浮式车顶
# 26                                       车侧.线条
# 27                                    车侧.腰线.风格
# 28                                   车侧.腰线.起止点
# 29                                    车侧.腰线.造型
# 30                                          细节
# 31                                         NaN
# 32                                    schema名称
# 33                                       轮圈.风格
# 34                                       轮圈.颜色
# 35                                       轮圈.造型
# 36                                        轮胎品牌
# 37                                   车门.外拉手.造型
# 38                                     外后视镜.颜色
# 39                                          车尾
# 40                                         NaN
# 41                                    schema名称
# 42                                   车尾.排气管.造型
# 43                                       车尾.风格
# 44                                    车尾.饰物.材质
# 45                                    车尾.饰物.名称
# 46                                 车尾.饰物.是否贯穿式
# 47                                    车尾.饰物.颜色
# 48                                       车尾.线条
# 49                                       尾灯.风格
# 50                                    尾灯.是否贯穿式
# 51                                     尾灯.是否熏黑
# 52                                          中控
# 53                                         NaN
# 54                                    schema名称
# 55                                    中控.饰物.材质
# 56                                    中控.饰物.名称
# 57                                    中控.饰物.颜色
# 58                                   中控.中控屏.风格
# 59                                   中控.中控屏.造型
# 60                                 中控.中控台.是否对称
# 61                                   中控.中控台.造型
# 62                                       内饰.风格
# 63                                       内饰.颜色
# 64                                    方向盘.底部样式
# 65                                      方向盘.风格
# 66                                     方向盘.辐条数
# 67                                  方向盘.是否双侧打孔
# 68                                      仪表盘.风格
# 69                                      仪表盘.造型
# 70                                          座椅
# 71                                         NaN
# 72                                    schema名称
# 73                                  前排座椅.饰物.名称
# 74                                  前排座椅.饰物.颜色
# 75                                     前排座椅.颜色
# 76                                  后排座椅.地板平整度
# 77                                后排座椅.是否有中央头枕
# 78                                         NaN
# 79  选图逻辑：\n按照车型粒度打标，选取任务一图片五级标签分类任务中已完成打标的车型图片
#
#                                                                                                                  Unnamed: 1  \
# 0                                                                                                                       NaN
# 1                                                                                                                        图片
# 2                              外观-正前\n外观-左前\n外观-右前\n外观-左侧\n细节-车头-格栅-正拍\n细节-车头-格栅-斜拍\n细节-车头-前大灯-左侧-45度斜拍\n细节-车头-前大灯-右侧-45度斜拍
# 3                                                                                                                       NaN
# 4                                                                                                                       NaN
# 5                                                                                                                       NaN
# 6                                                                                                                       NaN
# 7                                                                                                                       NaN
# 8                                                                                                                       NaN
# 9                                                                                                                       NaN
# 10                                                                                                                      NaN
# 11                                                                                                                      NaN
# 12                                                                                                                      NaN
# 13                                                                                                                      NaN
# 14                                                                                                                      NaN
# 15                                                                                                                      NaN
# 16                                                                                                                      NaN
# 17                                                                                                                      NaN
# 18                                                                                                                      NaN
# 19                                                                                                                       图片
# 20                                                                                               外观-左侧\n外观-右侧\n外观-左前\n外观-左后
# 21                                                                                                                      NaN
# 22                                                                                                                      NaN
# 23                                                                                                                      NaN
# 24                                                                                                                      NaN
# 25                                                                                                                      NaN
# 26                                                                                                                      NaN
# 27                                                                                                                      NaN
# 28                                                                                                                      NaN
# 29                                                                                                                      NaN
# 30                                                                                                                      NaN
# 31                                                                                                                      NaN
# 32                                                                                                                       图片
# 33  细节-车侧-轮胎整体-前轮\n细节-车侧-轮胎整体-后轮\n细节-车侧-轮胎整体-未确认\n细节-车侧-门把手-前门\n细节-车侧-门把手-后门\n外观-左侧\n细节-外后视镜-外后视镜45度\n细节-外后视镜-外后视镜正前\n外观-左前
# 34                                                                                                                      NaN
# 35                                                                                                                      NaN
# 36                                                                                                                      NaN
# 37                                                                                                                      NaN
# 38                                                                                                                      NaN
# 39                                                                                                                      NaN
# 40                                                                                                                      NaN
# 41                                                                                                                       图片
# 42                                                                                          外观-正后\n细节-底盘-底盘全景\n外观-右后\n外观-左后
# 43                                                                                                                      NaN
# 44                                                                                                                      NaN
# 45                                                                                                                      NaN
# 46                                                                                                                      NaN
# 47                                                                                                                      NaN
# 48                                                                                                                      NaN
# 49                                                                                                                      NaN
# 50                                                                                                                      NaN
# 51                                                                                                                      NaN
# 52                                                                                                                      NaN
# 53                                                                                                                      NaN
# 54                                                                                                                       图片
# 55           中控-三区全景-中控全景-正面全景\n中控-三区全景-中控全景-局部\n中控-三区全景-中控全景-侧面全景\n中控-三区全景-三区全景左-正面近景\n中控-三区全景-三区全景左-斜拍近景\n中控-方向盘区域-仪表盘-整体
# 56                                                                                                                      NaN
# 57                                                                                                                      NaN
# 58                                                                                                                      NaN
# 59                                                                                                                      NaN
# 60                                                                                                                      NaN
# 61                                                                                                                      NaN
# 62                                                                                                                      NaN
# 63                                                                                                                      NaN
# 64                                                                                                                      NaN
# 65                                                                                                                      NaN
# 66                                                                                                                      NaN
# 67                                                                                                                      NaN
# 68                                                                                                                      NaN
# 69                                                                                                                      NaN
# 70                                                                                                                      NaN
# 71                                                                                                                      NaN
# 72                                                                                                                       图片
# 73                   座椅-前排座椅-前排座椅整体-驾驶座斜拍\n座椅-前排座椅-前排座椅整体-副驾驶座斜拍\n座椅-前排座椅-前排座椅整体-侧面正拍\n座椅-后排座椅-后排座椅整体-正拍\n座椅-后排座椅-后排座椅整体-斜拍
# 74                                                                                                                      NaN
# 75                                                                                                                      NaN
# 76                                                                                                                      NaN
# 77                                                                                                                      NaN
# 78                                                                                                                      NaN
# 79                                                                                                                      NaN
#
#     Unnamed: 2  Unnamed: 3
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# 5          NaN         NaN
# 6          NaN         NaN
# 7          NaN         NaN
# 8          NaN         NaN
# 9          NaN         NaN
# 10         NaN         NaN
# 11         NaN         NaN
# 12         NaN         NaN
# 13         NaN         NaN
# 14         NaN         NaN
# 15         NaN         NaN
# 16         NaN         NaN
# 17         NaN         NaN
# 18         NaN         NaN
# 19         NaN         NaN
# 20         NaN         NaN
# 21         NaN         NaN
# 22         NaN         NaN
# 23         NaN         NaN
# 24         NaN         NaN
# 25         NaN         NaN
# 26         NaN         NaN
# 27         NaN         NaN
# 28         NaN         NaN
# 29         NaN         NaN
# 30         NaN         NaN
# 31         NaN         NaN
# 32         NaN         NaN
# 33         NaN         NaN
# 34         NaN         NaN
# 35         NaN         NaN
# 36         NaN         NaN
# 37         NaN         NaN
# 38         NaN         NaN
# 39         NaN         NaN
# 40         NaN         NaN
# 41         NaN         NaN
# 42         NaN         NaN
# 43         NaN         NaN
# 44         NaN         NaN
# 45         NaN         NaN
# 46         NaN         NaN
# 47         NaN         NaN
# 48         NaN         NaN
# 49         NaN         NaN
# 50         NaN         NaN
# 51         NaN         NaN
# 52         NaN         NaN
# 53         NaN         NaN
# 54         NaN         NaN
# 55         NaN         NaN
# 56         NaN         NaN
# 57         NaN         NaN
# 58         NaN         NaN
# 59         NaN         NaN
# 60         NaN         NaN
# 61         NaN         NaN
# 62         NaN         NaN
# 63         NaN         NaN
# 64         NaN         NaN
# 65         NaN         NaN
# 66         NaN         NaN
# 67         NaN         NaN
# 68         NaN         NaN
# 69         NaN         NaN
# 70         NaN         NaN
# 71         NaN         NaN
# 72         NaN         NaN
# 73         NaN         NaN
# 74         NaN         NaN
# 75         NaN         NaN
# 76         NaN         NaN
# 77         NaN         NaN
# 78         NaN         NaN
# 79         NaN         NaN
